# %% [markdown]
# Based on:
#
# - https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py
# - https://machinelearningmastery.com/develop-word-based-neural-language-models-python-keras/

# %%
import json
import random
import sys

import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding
from keras.optimizers import RMSprop
# Out:
# Using TensorFlow backend.

# %%
# load data
with open("../data/songs.json") as f:
    songs = json.load(f)

# cleanup & consolidate
text = ""
for song in songs:
    lyrics = song['lyrics'].replace('\r', '').lower()
    text += lyrics

print('corpus length:', len(text))
# Out:
# corpus length: 658180

# %%
# Tokenize text
tokenizer = Tokenizer(filters='!"#$%&()*+,-./:;<=>@[\\]^_`{|}~\t')
tokenizer.fit_on_texts([text])
encoded = tokenizer.texts_to_sequences([text])[0]

vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 20531

# %%
# create word -> word sequences
sequences = list()
for i in range(1, len(encoded)):
    sequence = encoded[i-1:i+1]
    sequences.append(sequence)
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 114333

# %%
# split into X and y elements
sequences = np.array(sequences)
X, y = sequences[:,0],sequences[:,1]

# %%
# one hot encode outputs
y = to_categorical(y, num_classes=vocab_size)

# %%
# define model
model = Sequential()
model.add(Embedding(vocab_size, 10, input_length=1))
model.add(LSTM(50))
model.add(Dense(vocab_size, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 1, 10)             205310
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                12200
# _________________________________________________________________
# dense_1 (Dense)              (None, 20531)             1047081
# =================================================================
# Total params: 1,264,591
# Trainable params: 1,264,591
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile network
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(X, y, epochs=5, verbose=2)
# Out:
# /home/dustin/miniconda3/envs/ML/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/5
#  - 59s - loss: 7.6193 - accuracy: 0.0485
# Epoch 2/5
#  - 57s - loss: 7.1009 - accuracy: 0.0493
# Epoch 3/5
#  - 58s - loss: 6.8332 - accuracy: 0.0579
# Epoch 4/5
#  - 60s - loss: 6.5959 - accuracy: 0.0806
# Epoch 5/5
#  - 59s - loss: 6.3829 - accuracy: 0.1016

# %%
# evaluate
in_text = 'how'
print(in_text)

encoded = tokenizer.texts_to_sequences([in_text])[0]
encoded = np.array(encoded)
#print(encoded)

yhat = model.predict_classes(encoded, verbose=0)
#print(yhat)

for word, index in tokenizer.word_index.items():
    if index == yhat:
        print(word)
# Out:
# how
# i

# %%
# generate a sequence from the model
def generate_seq(model, tokenizer, seed_text, n_words):
    in_text, result = seed_text, seed_text
    # generate a fixed number of words
    for _ in range(n_words):
        # encode the text as integer
        encoded = tokenizer.texts_to_sequences([in_text])[0]
        encoded = np.array(encoded)
        # predict a word in the vocabulary
        yhat = model.predict_classes(encoded, verbose=0)
        # map predicted word index to word
        out_word = ''
        for word, index in tokenizer.word_index.items():
            if index == yhat:
                out_word = word
                break
        # append to input
        in_text, result = out_word, result + ' ' + out_word
    return result

# %%
generate_seq(model, tokenizer, 'here', 70)
# Out:
# 'here in the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of the road of'

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 64

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 219380

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(
    x,
    y,
    batch_size=128,
    epochs=60,
    callbacks=[print_callback])
# Out:
# Epoch 1/60
# 219380/219380 [==============================] - 136s 621us/step - loss: 1.9174
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "s
# yea! heavy and a bottle of bread
# yea! "
# s
# yea! heavy and a bottle of bread
# yea! i’m gonna be the wide a findly the brand
#
# what i got a mone the said the mone
#
# i never said the book a stroin
# in the boor a long the back the trimber the word
# what i was a changed to the blown
# where the boon and i too book a long
#
# the boon all the the world your chain
# they know i’m gonna do in the the would do a blood
#
# the bear a far the shood the brown
# in the the was a money, i did the brood and
# ----- diversity: 0.5
# ----- Generating with seed: "s
# yea! heavy and a bottle of bread
# yea! "
# s
# yea! heavy and a bottle of bread
# yea! and the think is man fars
# that know that the this in what it do my head
#
# know who are the brownd the the wolld a dound
# and i all will be on my were the door
# and the the mood the black one the long
# i’ll you me the road in whee her would done
#
# we hands in my blood to the boon
# drown your more back the way the said in the the boot
# and i shold my plowers to the mone
#
# handy, know the money, the trouble
# ----- diversity: 1.0
# ----- Generating with seed: "s
# yea! heavy and a bottle of bread
# yea! "
# s
# yea! heavy and a bottle of bread
# yea! a liver good, hineraokate i leave the trowing
# someone in in you, xinnay the eledpss about bod,
# i and dragbdc bars and trunching in thuise
#
# i know be like my head, hoh,’llentiss, the kenttick on throon no myoesidreaf frackside her he did ma, dring
# how offarmor across a’s waocdrase
# and the moonly goeshannnting bectad
# everywhy?”
# wouth the strist a beid be turno
# sound of shoot ow yor a fell is crypiin
# ----- diversity: 1.2
# ----- Generating with seed: "s
# yea! heavy and a bottle of bread
# yea! "
# s
# yea! heavy and a bottle of bread
# yea! bloadr wishmed we’p lan on, yway,,?“
# truil, i wide long” bluid lofk
# ave jod a on uft
# back don’t go bah shocken ised jpints’retsitntealy dring
# you mone, , i’ll go do sroon
# whida disifncade wouldd
# forerclaln and hurd, kenor
# long
# out twop, miqued make wormaredi’bly ubloor
# night but or aarprans
#
# her slespley.
# why awistee tufess dowd up a bleade
# a kind over you gone
# hush there in donp in the ord is doo
# Epoch 2/60
# 219380/219380 [==============================] - 140s 640us/step - loss: 1.6087
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "but i’m still a million miles from you
#
# "
# but i’m still a million miles from you
#
# i can go the street for the more
#
# i can the more the moot the morning the more
# i can get your land and they says
# and they did the morning the streets the morning the world the mornin’ the window
# i can the world i can kiss to the broken
# i want to be the moon
# they walked the morning the stream of the stream
#
# something they was the stream and the street
# you got a hold the hold with you and they walke
# ----- diversity: 0.5
# ----- Generating with seed: "but i’m still a million miles from you
#
# "
# but i’m still a million miles from you
#
# i ain’ did the line
# it says is gone to the hole the world
# they’re gonna be drest be the trust
# she’s songants the line
# by the could be strengs of wonder of should
# you know the chimd could have to pay the anting it was the stream when they don’t have to the think you may
# in the world of the thing the bring on the down
# i can’t get your long to your the com
# to the mornin’ of the world the sece
# won’t
# ----- diversity: 1.0
# ----- Generating with seed: "but i’m still a million miles from you
#
# "
# but i’m still a million miles from you
#
# guttenin’ oncaw-le sto, love way yeah
# well, i way did the cits day
# when i tembsen over a pach
# they’re day the ckriys can ding,
#
# you’re rememberss thing mourt’t in bird
# the cendrapuss coulle it you whink then’t's once
# no alve lookin’ at him cold sun the me sighpay
# i puns spate to cailrapbo's in the
# ange too her strespteds all the darcigay, they were a coulhto deep’re nowhing what
# my think made on m
# ----- diversity: 1.2
# ----- Generating with seed: "but i’m still a million miles from you
#
# "
# but i’m still a million miles from you
#
# but you only wat a gromching at the drever’iet
# an i kid
# if ah,au's playin' of my nrambates clanes
# i did somephide
#
#
# take a piggamit greanting
# wey, you know you thre was eateon
# but i ne dop way
# i remember woeped runiess
#
#
#
# we then my cover magpinn, your mintroll marche
# i keep love, trumahing juck his norsam
# oh, they’re pintca thouhad dood
# ceemiforethe stould torn megreic yoars
# wentirg in megetedots
# Epoch 3/60
# 219380/219380 [==============================] - 129s 588us/step - loss: 1.5274
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "d lord lord
# i will pawn my watch and cha"
# d lord lord
# i will pawn my watch and change the wild better will see the last be the wild
#
# the sun the street of the stranger of the child
# i can stear in the lives of the world
# and i was the wild better was so the start
# the politic land of the stranger
# i was a things and the country be a morning
#
# the startin’ on the sun still the starting of the string
# the stranger who was a world to the way
#
# well, i can see the world of the rocks of th
# ----- diversity: 0.5
# ----- Generating with seed: "d lord lord
# i will pawn my watch and cha"
# d lord lord
# i will pawn my watch and change and gonna get you beginn
#
# the bend are the spere you long
# i could need you the road them could stand
#
# i went to the father don’t wish you went in the start
# i don't me the trees so the sawn and something her don’t can take him will see the more
#
# i can’t remember the one she had the world
# they don’t wanna be my cove on the somed down
# the shouth that we says on the hands something they killed the
# ----- diversity: 1.0
# ----- Generating with seed: "d lord lord
# i will pawn my watch and cha"
# d lord lord
# i will pawn my watch and change here
# look onter
# you touch the both quicket a so done
# the ci
# plew lord
#
# we glored be a kid be's a findy of comus”
# i pressey of too my sound
#
# ya whatever hare the sbagar nor or was mottenerdfes broke, pate tell you the failr
#
# you heal on my broken longerms scrues
# and he must be everybody's tell
# they bet a kilsad baby donge
# that he was it and hangold degre”
# i souding a ms forgvition
# on the carlin
# ----- diversity: 1.2
# ----- Generating with seed: "d lord lord
# i will pawn my watch and cha"
# d lord lord
# i will pawn my watch and chaince.
#
# will copinala
# if survisy mindbempody, well, he doss or that mousatal thandsome, to strajce right
# hamgiss decive wishli
# play mmd
# don’t have to the wormbows
# like nonn
# stelllyo, but af sonpip by down best puid i’m just rimbet and strike, the named riversbeen blabil, l?nickest
#
# i was everytainteorr
# big manded you could pleace, for scepes me,
# that hill, tookly sees at the shaden,
#
# ar not freak
# Epoch 4/60
# 219380/219380 [==============================] - 134s 609us/step - loss: 1.4832
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "ld
# if you just let me follow you down.
#
# "
# ld
# if you just let me follow you down.
#
# well, i got a train to the rain to the way
#
# i was a long of the streets and the street
# they say the way i was the start
# they say the streets of the start
# the streets to the rain to the black the street
#
# well, i can’t stand to the road to see the street
# that you can see the mornin' in the country to see
# i can’t see the streets and the street
#
# i can’t see me to the country to the street
#
# the streets
# ----- diversity: 0.5
# ----- Generating with seed: "ld
# if you just let me follow you down.
#
# "
# ld
# if you just let me follow you down.
#
# well, i had to tell your feeling and the seat of men to side
#
# the watchin’ in the can town with the lips to be his thing
#
# i was you lookin’ for you come and the diem
#
# the lord of laid behind that you come to love to play
# she to see i like the carfer or love, who never was the street
# they live they didn’t you wanna be sing the room
#
# we could hear to see the mother she diseps
# i heard the right to he
# ----- diversity: 1.0
# ----- Generating with seed: "ld
# if you just let me follow you down.
#
# "
# ld
# if you just let me follow you down.
#
# “what ain't not i've tonecomin’ that does in need
# and trouble down a hounts
# to, evendetain' in them to feel
# not the shall of monors
#
# well, i was madbed on the thing new,
# ’cause i'm tradl a so thaighs, it, so i woustters
# the rucns in smore, angelitionlyl highway get you and an' be t blessed
# you not reighted you sweet
# to your man who die you dig fize it and cres
#
# uncloow out of concer
# i said you kno
# ----- diversity: 1.2
# ----- Generating with seed: "ld
# if you just let me follow you down.
#
# "
# ld
# if you just let me follow you down.
#
# whista have did he was hadraighag’re
#
# well, or
# just are abratimes clj.desst
# fass saked medr
# dilwos song in place empi, get bbin'ed nobody o like no east
# and’s a mind, is i no deedly respod bbin on to the tol
#
# welr, i lought to stop them well, i medy
# well, the famblen yellin' ring wiriin's ’round fassing and knees to heary
# bald, iell silver a shelijudand boy uft'need t'le of twers of come
# is, thin
# Epoch 5/60
# 219380/219380 [==============================] - 120s 547us/step - loss: 1.4527
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "d trying to make a name for himself
# the "
# d trying to make a name for himself
# the sun whole things in the wind
#
# the walls of the walls of the sun could do it still should there they wall the wind
#
# there was a man of the sun
# and i walk a bumb
#
# well, i was a song the ranger to the lady of the door
# i was the rain of a strangers and the day
# i was something to the wall of the walls
#
# i was not gonna say a door
#
# i was a hold of the days and the day i was a stranger of the door
#
# i was
# ----- diversity: 0.5
# ----- Generating with seed: "d trying to make a name for himself
# the "
# d trying to make a name for himself
# the widing sometimes he said, “i love the wolls are bring
#
# and i walls on be the walls and the core
# i can’t come and of the bright
# from the bottor of your coor
#
# i was tomorrow i'll see the core of road
# well, i’d been gone but i was somed what i could give you all and the morning
# they a hands of the traveling
# it’s a nobody can’t know the window
# you we who say what you don’t wanna be the wind
#
# well, i c
# ----- diversity: 1.0
# ----- Generating with seed: "d trying to make a name for himself
# the "
# d trying to make a name for himself
# the sun load from your houst'll ya can think you were or'
# that i can't muse for your peatet man o drews sant
# then hald incllowicarigo seesanding mmrning
# we could still wingle there with you
#
# he said, “well a sart world
# i danery tell araym a mat
#
# it’s ioredshil the cumbalach holes true like a satili-’
# i reops in the stace ooth
# i'll watchers must  as ship and light more
# you’re as bluesed down your more
#
# ----- diversity: 1.2
# ----- Generating with seed: "d trying to make a name for himself
# the "
# d trying to make a name for himself
# the ngign man flyin’ it’s gote
# you wouldn’t ’wun naverive fighting asker roy sbering
# where dolllyceny hand, one tare gift
# decighting wying you get night
# in makes one laon, but the get laud
# i’ve got the tatubot unsrealver“fleces willing you a ne.
# got so here-down nith to living it
# pushed mouery
# smepity louar yalls are sadn i say
# peppean, ne, clothed
#
# grab got a bower wrongnee
# do in spark
#
# gwil before a
# Epoch 6/60
# 219380/219380 [==============================] - 123s 562us/step - loss: 1.4286
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "
#
# you can’t take it with you and you kno"
#
#
# you can’t take it with you and you know i can’t stay to the street
# well, i got a dirty to the wind and the streets of the street
# i said to the streets of the streets and the sails are all the street
# with a man i can’t stay to wait to do
# in the sun in the wind and the wind to me to the street
#
# i was not the street and the contress of the day
# i was not the wind in the sun in the street
# i was not the stars to the street
# and i was a man i
# ----- diversity: 0.5
# ----- Generating with seed: "
#
# you can’t take it with you and you kno"
#
#
# you can’t take it with you and you know
# i see me to work to ya met your highway
# for you may hard to see it still got to say i said to step into the streets the next davey and the stectin’ you and i was not the more them and the wind my head
#
# i passed in the said was too street
# i will forgot and the line out of somebody wanna feel it went to the corient
# all i'm so girled with a street
# she ain't got a shot of the walls
# and i will said t
# ----- diversity: 1.0
# ----- Generating with seed: "
#
# you can’t take it with you and you kno"
#
#
# you can’t take it with you and you know
# nothing off the sun off.
# it’s only seems are o forty-all-door
# and i’ve yer boy, ware my life and the more sing tonight tonight the birty
# and cetter year dboon upon my shalio
# new young burning
# i said comes me house her,
# i know the soue to me
# the raind place at blood
# takes baby, i caught all a eercal rough myied
# if you wanna die dows,
# all you just know they blind to  strock doin’ agrow
# blowin' her
# ----- diversity: 1.2
# ----- Generating with seed: "
#
# you can’t take it with you and you kno"
#
#
# you can’t take it with you and you know i just’t say i'm suppinals's closed
# forgot to the old man,
# so all it like a seest for home
# as rollin’ up and is
# night it wasn wiod
# lardpol ow ovfyboy’ll girl sunn times we’re
# orchoway, ehou this orled go-halled the tex, so talkin’ eaches forgyting,
# if you know a man floors about you wongat
# pusay walked up that her into in ever’t out commi, mimd
# i’m lovenin’ the fate, baby
# pregisen rebe, or bily
# Epoch 7/60
# 219380/219380 [==============================] - 122s 556us/step - loss: 1.4136
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "n crucified
# do you have any idea why or "
# n crucified
# do you have any idea why or they could be my heart
# they say the streets of the track of the streets
# with the boot of the streets
# where the street of the streets
# with the streets of the boots and i want to the land
# they can take to the streets of the window
# where they can take that i was the street
# where the wind with me and i walk to the window
# where they stand the wall to the start
# they seem the streets of the start
# they sa
# ----- diversity: 0.5
# ----- Generating with seed: "n crucified
# do you have any idea why or "
# n crucified
# do you have any idea why or that you don’t know my head
# but i know that you can be standing and i walked a courter of the boot
# where why is they walk to the neighborhood of matter of man would be stay
# when i walk you walked on the world or the track stars
# i was too it with the streets cryin’
# and the walls are without the country the dee
# i want you to the line
# they sister to the streets of man i want me beating to step
# and ye
# ----- diversity: 1.0
# ----- Generating with seed: "n crucified
# do you have any idea why or "
# n crucified
# do you have any idea why or if that through his lead as the star
# who are true, love to they're walkin' son’t the day
# the swaal i lot walls and are well
# babe when three winger and then it agreave a pook of him no sed
# i was your sun, like no remore hwey me
# you can standin’ up this and matthen a words
# a rossing of my round from swicks
# i wime in my, i’ll gets waited in oughts
# without you on your walling
# an’ for these open that's
# ----- diversity: 1.2
# ----- Generating with seed: "n crucified
# do you have any idea why or "
# n crucified
# do you have any idea why or where the mirrales was skil
# and they spy pass then sidew of tho cureans
# but that i’d fum up to lle?”
#
# in if can’t be stick for medon
# pet, did ’aton
# tangle orcans oqdee. 'neathter head in atdiug, but ain't a re
# walkin’ on the itrees, senseded as he have inside
# that so full up was reallen, go throght said,
# “that you masty hurt
# lebs uligh up to bring again anyway, which down were.
# i did walk to to ca
# Epoch 8/60
# 219380/219380 [==============================] - 132s 603us/step - loss: 1.4017
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "nger
# from eli he did come
# with a mind th"
# nger
# from eli he did come
# with a mind that i want to the street
# and i want you and the window
# when the wind bell of the child of the bend
# i was a stranger she was a country the rain
# and the way in the hand
# i want to think i was something to the wall
# i want to tell her the way
# the wind bell the line
#
# i was a can see the start
# when the way i want your back to the seas
# and i was a long as something in the dirt of side
# and i see the street
# ----- diversity: 0.5
# ----- Generating with seed: "nger
# from eli he did come
# with a mind th"
# nger
# from eli he did come
# with a mind that i got to tell see me and a man
# but i ask you in the dead of last new were singin’ you are the way
# i don’t look all the dirt and the than you see me for the wide
# i was a heart a best be was say
# well, you could they look a sound that i can’t see
# and the county of me in the mornin' on in the start
# when he’s a heart of the probind
# they be the sensen the way i don't wanna be star makin’
#
# the corner
# ----- diversity: 1.0
# ----- Generating with seed: "nger
# from eli he did come
# with a mind th"
# nger
# from eli he did come
# with a mind they back a band in your mindcap,
# pift to see where good, alm you
# or the halls was shint
# now got the stars birds and on o, the pater of hooden tells
# tell what's anywe drink to be lint
# i ain’t come in the door
# and it’s come phirlw
# she putter all lord of the end
# that she’s thnoboned over the truth
# and can’t know no sallaw
#
# the please and cap
# she prinkin' at me a moen is on the world
# has shy’s a a hear
# ----- diversity: 1.2
# ----- Generating with seed: "nger
# from eli he did come
# with a mind th"
# nger
# from eli he did come
# with a mind that rewaid across in a sift a
# give playin’ of lift
# in gibose by name a -bother, honey bring
# big morea
# i’d hallin’ caredrsganin’, “i’ll be you, fornsisnsky
# in a time if i mekted you beat?
#
# i meal yet much, what its might sit of hunive over
# well can’t say youvel stripped
# nobody say o. looks off i’m w't many iuch, everything night, high away cord
# ’ronged away thunger hander heaken’n’s after you’ve cov
# Epoch 9/60
# 219380/219380 [==============================] - 130s 591us/step - loss: 1.3890
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "istance
# yeah, the locusts sang and they "
# istance
# yeah, the locusts sang and they can that you want to the stars of the road
#
# well, i want the day the street and the start of the morning blues
# the start to the start to the start to the stars that i was the start the blues
# i was that the thing the thing the start of the start the start the train
# i went to the day the time they can take the day
# when the street and the shot of the time that i want the stars that she was the land o
# ----- diversity: 0.5
# ----- Generating with seed: "istance
# yeah, the locusts sang and they "
# istance
# yeah, the locusts sang and they said who said i still be dreamin’ on my way
# the shoot me and the not the day
# when you can take the day
# i was not foot the bound
# the boys to the song of the night
# well, i go a man went to the walls and it’s stall
# what need my love the houser and the rain”
#
# well, i’m gonna go about so the start in the sky to be the start of love
# i won’t be starters that you’re gonna work the chourdry say
# i went to k
# ----- diversity: 1.0
# ----- Generating with seed: "istance
# yeah, the locusts sang and they "
# istance
# yeah, the locusts sang and they dressder stripped to be
# and mayon’t don’t ever been nobody cared onexemiy will waited of the condea much
# she ain’ willfles pittin’ from the moke and walkin’ on him rrack
# when i can be heading hill then
# old last young the road
# baby, i’m on your hopes
# on the prisits gets
# you can’t cain’t gottee a show longingone one leve that you’re gonnanat, he weet
# and gone, with the
# we specking that has given’s
# ----- diversity: 1.2
# ----- Generating with seed: "istance
# yeah, the locusts sang and they "
# istance
# yeah, the locusts sang and they gotta re
# well, yes, do i in, i said, just own fateling dallin’ whysiaodvays
# try someefrop the scarty
# there’s times to aerpea my truck
# to know for trouble while and stand upor
#
# father bloody do?ion't every here get man
# a hptch high dobi’t of knees, got wiggoting head
# behung, i wuss the girl ando!o'sag-baby, liftin' for en’?
# “nouble goodwell, we’re not jet's sention, that hills
# then clauncy, owneds
# Epoch 10/60
# 219380/219380 [==============================] - 133s 607us/step - loss: 1.3799
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: " a-gonna hang around here
# ain’t a-gonna "
#  a-gonna hang around here
# ain’t a-gonna wast you to the start
# and the streets of the way
# so you want to see the story
# i can say that i said the last the streets are a storm
# i was were a long the start
#
# i can say the heart of stall
# i got a heart of a stall
# i was a far and she ain’t no gone
#
# the streets man in the way the way the start
# the streets of the way i was start
# the startis a strangel to the start
#
# the streets of the world and the
# ----- diversity: 0.5
# ----- Generating with seed: " a-gonna hang around here
# ain’t a-gonna "
#  a-gonna hang around here
# ain’t a-gonna wast the trailolly still said my song on the live that i said she went and he took a hold
# but i was yourself the stetion are some on the light
# i got the whole bells and the white can you say a string to may
# i can see you you say my pass
# i got a distance
# and i was the car’s room to see it to the morning
# i know i know that the last the sawn to the street
# but i just been love i was stand
# i got the wh
# ----- diversity: 1.0
# ----- Generating with seed: " a-gonna hang around here
# ain’t a-gonna "
#  a-gonna hang around here
# ain’t a-gonna cay me do vigct she hand
# went to call god faith
#
# away terest on the ben tight
#
# whiffa someorliy’ play a nkeiges of ne,
# and did you get that the fath
# pay, well ’em blue citions
#  ursthoound
#
# i wanta never look about it in a hath
#
# leave stole weet your po-fid wi'd iny dooling sunta from the ground
# this weyes' cirdie know
# to the feeles iel in
# '
# i said a roston must, baby, oh-alghoude
# igo their rabin’
# ----- diversity: 1.2
# ----- Generating with seed: " a-gonna hang around here
# ain’t a-gonna "
#  a-gonna hang around here
# ain’t a-gonna gues dow, it’s been moet’ll foreve
# polf empteciulanngend chot dufe
# whenery, wander floss my vent
# when peaple pites, wouldn’t want your hist tawrs
# day you winh you still he know my ponwe bemirsslife thenh somebody
# the bauth house like whisparuck, miss fe lifeed around
# they’re l
# fhthe
# for i corldowe and cold
# i rude my twoncecgo was, we’re nothin’ go lord
# death there’s a gun, care and ten youths for
# Epoch 11/60
# 219380/219380 [==============================] - 142s 647us/step - loss: 1.3703
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: " in the wind, babe
# when i'm out in the w"
#  in the wind, babe
# when i'm out in the world of the cross
#
# the same the sail of the crows
# the can the sun can be startin' at my mind
#
# the way you want your head in the line
#
# well, i can start the road is here thinkin’ back
# i can start a man in the streets
# and the sun can be all about the street
# when the streets of the back of the cross
# the sun was the could be started to the line
#
# the sun can be a long time the wind
#
# the sun can do the
# ----- diversity: 0.5
# ----- Generating with seed: " in the wind, babe
# when i'm out in the w"
#  in the wind, babe
# when i'm out in the way you want to you
# hand in the road was out of the day
#
# sing my bed that can i know the dead in the morning
# the load along my feel baby, the streets and he were calling and be for the flows
# the shook a crap like a sounds on the child
# i can stand good for the moon of the sall
# and i see the concertantn the came of my price
# don’t let stone you someone can't gonna get me in the crows
# to browns i got t
# ----- diversity: 1.0
# ----- Generating with seed: " in the wind, babe
# when i'm out in the w"
#  in the wind, babe
# when i'm out in the way goin’ blow, long
#
# you gonna live you old brownss, don't seesly
#
# i’m lockin’ on the day
# he seen you that
# if you weed doot sitting in my
# i can make it how the shiplle inturned
# say isleache wourd
# dadget, just was waketted haod and me
# but througr me go like to there
# wintstalicisu’l baby, baby that grfictlude
# if it meaned yourstleluse around
# i'm a-ween a whole wefe’re hered you sends the morning tig
# ----- diversity: 1.2
# ----- Generating with seed: " in the wind, babe
# when i'm out in the w"
#  in the wind, babe
# when i'm out in the wondays
# and littlemat to you adone rain
# my party down, i inved
# while slaucho, yee a grauth babedgettin’
# to geth fends judint off
# gonna make a enry that i us—sheas away, when he lay to friendt
#
# yer , they was the disenstla
# i tried to miss thrown that you look for you
# everythin’, that’s thrown evil think, he bested me through
# but apsare deconders
# rivghodise, i'm fauelyn’t even on in the hatusy
# back
# Epoch 12/60
# 219380/219380 [==============================] - 123s 561us/step - loss: 1.3605
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "
# tell me what you’re gonna do
# when the s"
#
# tell me what you’re gonna do
# when the sun and the way the sun was been thinkin’
# the sun is a black of the story
#
# i want to the street of the street
# where the way the wind of the street
# the sun is so the way the sun and the street
# the way the window of the street
# when the way the wind of the world
# i want to the sun and the wind of the story
# i want to the stand of the hand
# the way the sun was been the stand
#
# the sun and i see you to the
# ----- diversity: 0.5
# ----- Generating with seed: "
# tell me what you’re gonna do
# when the s"
#
# tell me what you’re gonna do
# when the sails are sayin’, “i saw you shoot me to do it to the bring
# the count of the hard of the conceition
# why hope to hear a dream ahound
# lord, but the breals of things are stare
# the pale song have trisous day the world.
# they shocke in a mind
# i was punnin’ the man are you ain’t a man thinkin’
#
# i don’t know the songs of track by the river rock
# and i can throw me the back of the world
# he told down the futt
# ----- diversity: 1.0
# ----- Generating with seed: "
# tell me what you’re gonna do
# when the s"
#
# tell me what you’re gonna do
# when the stones can be i netting
# you tell i wold farest het
# you were trouble will sboul and the good
# but you’re voie cmoude pearled
# thinks that the time something the air
#
#
# oh fareween up and they are say
# catwo rose them to the stm the floor
#
# why deal filled, all no hime on the chois
# you’re been sistleddated are
#
# tell my day i swear and as the time the right gabin
# you don’t have to make a kid
#
#
# won’t in the
# ----- diversity: 1.2
# ----- Generating with seed: "
# tell me what you’re gonna do
# when the s"
#
# tell me what you’re gonna do
# when the sup
# and a meaning of catried
# ahenma, but to i have the night hookin’
# searches called ’ching him man
# who he laughned that’s the demmerty risamery man drist passe
# but he was a hers keep me
# then you’re many bfat to whiney
# you’s gone, i won’t hat my rouge hourh jaby
# was ’neath the sun clrin
# was boved cayertay?”
# he to your place again
# something you’re faffy coman needdy
# jing after long the tidow, comin
# Epoch 13/60
# 219380/219380 [==============================] - 123s 562us/step - loss: 1.3552
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "d
# just-a one kind favor i ask you
# ’low m"
# d
# just-a one kind favor i ask you
# ’low me to the street
# the world of the streets and he said, “i’ll be a friend of the street
# there’s a street will be stare
# i could hardly gone
#
# well, i was a man was a blowin’ the street
# the way i was the street
# the wind and the world of the street
# the street was a long the street
# when the street was but i said and the world of the world
# i can’t stay about the way i was but i was the wind
#
# the street wa
# ----- diversity: 0.5
# ----- Generating with seed: "d
# just-a one kind favor i ask you
# ’low m"
# d
# just-a one kind favor i ask you
# ’low me and the street man better have but
# i can ask again and you that put me down to share the conoron look and the wind
# and i sure all the streetwell leave
# she got a broken are on my baby and the wildor world
# when the siller to the edge with the should and i got a conden to the little talk
# you wanna go to the street
# and i say, “where the town for me in the orney
# when the streetlem was with my head an
# ----- diversity: 1.0
# ----- Generating with seed: "d
# just-a one kind favor i ask you
# ’low m"
# d
# just-a one kind favor i ask you
# ’low me desays i knew it’s not slow
# and a oney and the world
# well, the way as bloodin’ a man
# hope that bount around with gross times
# again’ it in the houl
# my flowing coming upon his bamked down where the thiol’s richer world
# can’t ya tell ’til down, the wolling busting
# but it’s all kinds in fronking, i stop likes
# you got about a leel take
# she his
# oh sun and the inseep like nothing smith
# well, the lown’
# ----- diversity: 1.2
# ----- Generating with seed: "d
# just-a one kind favor i ask you
# ’low m"
# d
# just-a one kind favor i ask you
# ’low me chbernak i'll nearle
#
# ”
# when
# when the grien and shadow if ’oen’n menstaircast
# dome, all be clet
# whollel the sonded like i’vee just namen way
#  go, she’s gonna ch?
# so dead tegred thats i too
# you wangpine to leave you woll
# down the birrors are failsshint upround
# and burnin' up nons
# she’s when tel“street, yesh'srapp lawing down emonlovensts
# and jula’s lices wula, now byed
# the treation of her blowin’
# Epoch 14/60
# 219380/219380 [==============================] - 137s 625us/step - loss: 1.3491
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "an asked me who i was
#
# i repeated that m"
# an asked me who i was
#
# i repeated that man in the wine
#
# well, i say what it was the streets and the way to the world and the soul for your man will be a man
# i was the same the time is say
# with my head and the song i was a time to the train
# the cond standing and the water to the sound the time in the wine
# i was a hard to the sound
# and the wine was a man in the world when i don’t have to see you
#
# i don’t know me to make me to the sound
# i
# ----- diversity: 0.5
# ----- Generating with seed: "an asked me who i was
#
# i repeated that m"
# an asked me who i was
#
# i repeated that men a chance, it must have to me
# and i got a hold to the tries bless
# i was the mishin’ like a day
# and you’re no woman and the winking of the little mind
# they know the boundoner then you'd got everything with my bed
# i said the sally could have to me that down to make me have be another man
# when the trummenty is like i got me to hum
# i wouldn’t take a neighbor to the wine
#
# i can tell you me and to the
# ----- diversity: 1.0
# ----- Generating with seed: "an asked me who i was
#
# i repeated that m"
# an asked me who i was
#
# i repeated that merviest,
# the main joyey thearing a blops
# two t?ed life up breems
# and i put a senst, the bringin' lifing fretntheon lock
# in the hair sound the door, jonetheress, farest their time they are but i see the chairsuppet, down says, lettepest all twee in
# just just medomy caughts out what
# and a true love and is out them in my wick, old mama, ail’t walked time and my friend, shake my sparkaruse too lady
#
# a
# ----- diversity: 1.2
# ----- Generating with seed: "an asked me who i was
#
# i repeated that m"
# an asked me who i was
#
# i repeated that man itor
# oh highless you beginning
# you’re roadbles champled engrent to wine
#
# ove lookin' at nicking, even through,
# and bfotter wherenight, i radlem, it was the trippor barn wonderdror's the dark iver over’try getwe me, oh’s jumen
# about he’d feel in the constansiliftomy
# scalway so tettat
#
# hoed, you've askied your men was haughijam dengedesy
# and we canny
# i could i walk anything, to bett my gettendel’
# Epoch 15/60
# 219380/219380 [==============================] - 167s 761us/step - loss: 1.3417
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "from me this moment”
# i told her with my "
# from me this moment”
# i told her with my heart
# there are you can see the song and the same that i want to be the same
# in the song of the street with you in the same
# i was a miles to the song of the window
#
# well, i saw you got the track
# you can see the track of the street
# and i say with a chilly for you to the song to the sun lookin’ and the window
# and i want to the same the dead and the sun that you got a hold of the street
#
# the sun in t
# ----- diversity: 0.5
# ----- Generating with seed: "from me this moment”
# i told her with my "
# from me this moment”
# i told her with my door, she can’t see it in the sound
# with them are you may be so her the street
# the things that i think you know
# man with the dasse for a politiple man she had a onlane
# she said, “ne, it’s not see
# the track of the one i could be so six life and the news
# i had to tears in a morning
#
# when the land of the street of man been a memoring
# and i broke it all the things and the back of his side
#
# poor the wh
# ----- diversity: 1.0
# ----- Generating with seed: "from me this moment”
# i told her with my "
# from me this moment”
# i told her with my own he did voice
# as tooogen when you knee my heart
# when the coatwell, i’d a pease to hell
# that she filled up thinking
#
# now missus just like a dark
# for you someone crues my love usino
# and then he be yon i never truna dark to me
# when the never poudrair wisled, pushees
# i looked them magd tink
# bethanin fines like a beck,
# he run down to dark
#
# i'm just love thinking of a brave thatfing more than the tor
# ----- diversity: 1.2
# ----- Generating with seed: "from me this moment”
# i told her with my "
# from me this moment”
# i told her with my live ain’t bivent
# never tooa them bfedsire
# all duddly of my ride in meth
# ih, feel you hagnen’ unitin’?
# oh let her girlips am tell it
# oldlea daysreians beneathe
# phin
# thgoe fold hididded, i brink that gets
# bick her row,
# tonight between your man talk and then hung of i must ask me
# bue do you like that young
#
# and dyen’ neeled wheel lies let jiepers she wants you .    dice down in
# i'm goiding that ine’
# Epoch 16/60
# 219380/219380 [==============================] - 149s 677us/step - loss: 1.3359
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "and the lightnin's a-flashing and the th"
# and the lightnin's a-flashing and the things and the way the street
#
# i can’t call your wooth baby, i don’t leave me and the work of the world
# i was a heart to the sun
# and i can’t know what i wanna be your wood and the wind
#
# i can’t reag to hear you the true
# and the wind block of the way
# they’re gonna grieve no more
#
# i was a can in the window
# when you wanna look the more than you want to say the stars
# the black of the window
# and i can’t
# ----- diversity: 0.5
# ----- Generating with seed: "and the lightnin's a-flashing and the th"
# and the lightnin's a-flashing and the things to the bend if i say
# what i pick the street
# and the one that you can see the heavin like the world
# i was a heart of need sang
# but i can't see the reason
# when the window, shine your eyes
# but it’s you trying to mornen you to steal go me
# you can’t see you the break of street
# it’s all not come in highway
# the wind block to say it is all asplay to me
# it’s a stalling and the wind
#
# well, i go to stay
# ----- diversity: 1.0
# ----- Generating with seed: "and the lightnin's a-flashing and the th"
# and the lightnin's a-flashing and the things of you, be feets
# in chained the heast room
# up on steple untersor’s goin’ asceflie with sriblethuh
# it’s sing it come with discorne
# strand at so bread
# why didn't put vood a maysel in yeth that ma-.hel early, "hhy, you done mudde in
# or some sieve were is young
# from wyere, the onely can’t have that made the pold wanted no love
# you want iprescise where the lor
# yeahrolg, kitchea fromsius did rock
# i
# ----- diversity: 1.2
# ----- Generating with seed: "and the lightnin's a-flashing and the th"
# and the lightnin's a-flashing and the that for ma sucking the day, propo, wantin’ the necture
# my road iren littly bock
# theeess then not right away
# everybody was casted two the time
# honey iver the sun to a
# her shor’prowns,
# but the throle was
# nobody just wale thinking you who wondery rive
# her ain’t driving tettere who leard they puts to do you this
# decih times ma
# they’re a road, there’s durt a flame, you’ve gong bulls
# let neple the haril
# Epoch 17/60
# 219380/219380 [==============================] - 145s 663us/step - loss: 1.3314
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "t brings back a long-forgotten truth
#
# su"
# t brings back a long-forgotten truth
#
# supper the bend of the street
# the wind of the morning blue
# i was a man with the rain
# and the sun can die to the sun
# i was not the street
# the wind of the country been down the line
# and the wind and the wind
#
# the wind of the line
# i’m standing and the water to the street
# the sailor's a hold of the world was a man with the wind
#
# the sun can drink to the street
# the sun can the sun can drink to the street
# ----- diversity: 0.5
# ----- Generating with seed: "t brings back a long-forgotten truth
#
# su"
# t brings back a long-forgotten truth
#
# sucked and the line end but you everybody and grow the line
# let me says, “and the best and so the cold of love
#
# i was a friend of the days are all the curice
# the times and the shook and not to get send to do ain’t goin’ in the will
# but i can ain’t got no are the stone
# and the morning were here to make steal
#
# something we was not to do
# will was gonna make me to the motho are from the are with my back
# ----- diversity: 1.0
# ----- Generating with seed: "t brings back a long-forgotten truth
#
# su"
# t brings back a long-forgotten truth
#
# sure bene, i’ll by you and sally, shall hard
#
# the bandley wear muchron doon
#
# why to cold id, wigh over toll the nights and my words
# and then where why there’s stont miles and ten goin’ loneu’rt cold of rain
#
# lights to be in his uppersed all ralgn’t deal
#
# the name with your ockition gosemth oh, the poor playin’ by mynime's shoensin’ get is not perfeven my light hey”
#
# nowhorise you must stambline, isc
# ----- diversity: 1.2
# ----- Generating with seed: "t brings back a long-forgotten truth
#
# su"
# t brings back a long-forgotten truth
#
# suve albert smiles and trackac oilo, to the boice
# with your dayausteowed down
# night meama walked
# the railrot doese, i don't gonna needin’ into be all patewal
# somethin’ imchibe
# my old to the unffter out she had blows
# just when ywe walked for the sky
# fire rood to need again
# whistle dyow, mabe peclball no one blame
# the cfoke thoogsty is sister form wight up and toill
#
# i have no all mban
# i this ms
# i’ll
# Epoch 18/60
# 219380/219380 [==============================] - 155s 706us/step - loss: 1.3270
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: " was reflectin’
# the fast fading words
# th"
#  was reflectin’
# the fast fading words
# the way you know i want you
#
# the streets glad it was a morning the stars
# and the way i was the starters of the stars
# they don’t be all the stars to the street
# the strent of the stars to the starter the strent
# i want you that i want to tried to the starter that she was the street
#
# i was a train to the bottom of the day
# i want you and the strength of the street
# they said they said the starter that she
# ----- diversity: 0.5
# ----- Generating with seed: " was reflectin’
# the fast fading words
# th"
#  was reflectin’
# the fast fading words
# that someone see the strange
# but i was the way you know i don't have to trie
# i said we got me to see your hard
# that not the war that i ain’t nothing to hear
# she was my dead and the way
#
# the well through the stars to have been a morning
#
# i want you in the things that you know
# but my friends with me to the street
# the orve was a storm the bringing of the stranger
# that good of the bosk the sating throug
# ----- diversity: 1.0
# ----- Generating with seed: " was reflectin’
# the fast fading words
# th"
#  was reflectin’
# the fast fading words
# through the mode of getaine, conagylus of like i met to the ballin', black
# throng of
# threuther someone can you llow away through these lips sown
#
# it is freedownpall o, he cut me up a hill, i can be a arm
# tdear now
# ald men i he feet in there sound youe
# took a servain windout you cat
# she dooled someund to have your smips
# they’ll be denget askice
# do you take
# just just when the endhone
# to be twneer ta
# ----- diversity: 1.2
# ----- Generating with seed: " was reflectin’
# the fast fading words
# th"
#  was reflectin’
# the fast fading words
# this evenamer was muck
# someone see her toilipe the willrained, too
# other ting pales
# and dripperfud uf dresseding slips of the day
# oh, frogholure one time.cops left mayarts i soft you mum?
# well, you turnlies me’rrst broan
# through th
# /home/dustin/miniconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# ough herembileadin’, ayowelce ’em bat, mude, baby, lying i wonde’s gettin’ me up one teruste
# the war toivis gites named dark on, little or
# we peiden ax-agatws around, i’m
# Epoch 19/60
# 219380/219380 [==============================] - 137s 624us/step - loss: 1.3214
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "undred wives
# well, ev’rybody’s got somet"
# undred wives
# well, ev’rybody’s got something
# i was a hold of the day
# i was the streets and the way i was the stone
#
# well, i was the stone of the way
#
# i was a shot of stranger in the stream like i see
# i was a shot of stranger and he was the stream
# when the dead is an arrife and the wind
#
# if i was a hard of the story
# and the things and the world of the conceor
# and the stream like a song baby
# i was the rain of the street
#
# well, i was a han
# ----- diversity: 0.5
# ----- Generating with seed: "undred wives
# well, ev’rybody’s got somet"
# undred wives
# well, ev’rybody’s got something
#
# in the high wedway comes on the boss with the morning kind
# to the shadows of the world
# is they stop to see the lord
#
# if i go to be all i see your seemess in the hand
# and like you look about it as like a sad
# don’t the next tine
# and they can get the end, please walking
# they’re leaving the songers of a places of heart
# and the time that i’m standin’ where the bonest she’s on the bring
# and they w
# ----- diversity: 1.0
# ----- Generating with seed: "undred wives
# well, ev’rybody’s got somet"
# undred wives
# well, ev’rybody’s got something
# and i had the rag of i'll stob
# lensthorss me not they
# her hope, they’re come vain
# leanings are walkin’ on a dignitic abroumeven hope on the main-owile was strucking and her father stone?
# hope you came from the show sword, it, honey
# and it’s not read
#
# i’ve said they did the well
# cagry, heaven all an, muhige get carity and they hear?
#
# faie someway, you’ll be they wall the surped where a bones t
# ----- diversity: 1.2
# ----- Generating with seed: "undred wives
# well, ev’rybody’s got somet"
# undred wives
# well, ev’rybody’s got something that's you?
# it wisfusm test shigh ton
#
#
# madey, said curds
# and i.
#
# there's a house i’m truthing around to do ugodeen the strung,
# and care gon out of a diamonds
# flows to be twich to youthent four doon
# did catter and far aysiskulr, by best of morning for you’ve you.”
# sas-ey, sicifid, many, wide you wand
#
# rolls watchom in crosc maggie's last
# my time kinds a finkings if something like gom fasenion
# Epoch 20/60
# 219380/219380 [==============================] - 146s 666us/step - loss: 1.3166
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "ise the good lord to get her out of your"
# ise the good lord to get her out of your face
# who was the sun will be so lone
#
# i can see it was something to the street
# and i can see it all the shore
# i can see the morning the window
# who was the window of the sun
# and the window of the shore
# i can see you all the shore
# i don’t know that the sun is so far and i was to say
# they throw the country standing the shore
# i was a man i can see you
#
# i can’t stand it was the shore
#
# well, i was come
# ----- diversity: 0.5
# ----- Generating with seed: "ise the good lord to get her out of your"
# ise the good lord to get her out of your hand
# i can take the mind for your could be in his hands
# someone was a million things that you can have to say
# i was the steal in the gallart even the window
#
# well, i don’t know that shelf i’m in the end
#
# we me to get get up and he can worry
# the could stand of the lonesome back
# it was we goin’ to say
# i can stand it ain't in the dark some of the darkning by right what i was to go to the well
# and a
# ----- diversity: 1.0
# ----- Generating with seed: "ise the good lord to get her out of your"
# ise the good lord to get her out of your besittee
# where the same, i don’t vot you
# on the thing there as a diamone with a man of kint
# when a himmlew are falling the other from the chilly knows, got been lover enolor.
# i could not be then, rain
# because you met the change cried
#
# and i could lose you knows
# i can get weary
# you in a blaske in a time
# from the courys miw
# when i level got like the busn’t humd on to get fby is learning dar
# she ain
# ----- diversity: 1.2
# ----- Generating with seed: "ise the good lord to get her out of your"
# ise the good lord to get her out of your thood
# wasle best apopw.ho dene you got away
# ain’t knows another outha lover
# someone’s gonna need te.strip canderd john ”
# crance them getting pirned
# i must cake the pountslood to the king and could
# tocoach’s huf
# turned igrod forty mone my eyes
# i’d don’t be
# giveg but blint
# was arubale, bikem,
# well, i never had godfitter
#
# santons trbicy, sider he whis bless, hennin’ got torn apstiof?
#
# disragiron,
# Epoch 21/60
# 219380/219380 [==============================] - 148s 676us/step - loss: 1.3148
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "om me to you
# tangled up in blue
#
# i lived"
# om me to you
# tangled up in blue
#
# i lived the sun don’t be stand
#
# you wanted to the strength
# oh the windoose the street
# the sun don’t know the world where the sun can star
# and the world where the sun can street
# where the sun is not the world will the sun
# i can’t stand a song the window
# i say it was a mornin’ in the world of the light
# when the sun can the world i was when the street
# i was worth and i was steppin’ the day they could see th
# ----- diversity: 0.5
# ----- Generating with seed: "om me to you
# tangled up in blue
#
# i lived"
# om me to you
# tangled up in blue
#
# i lived lay down to the rain
# and the same is tellin’ back in the window
# and i won’t see it you and the trail of the waophone
#
# the water of the line
# and i’m a woman and i won’t even war was a picture in kind of things of grown
# i can you see the road
# and the man of the time i getter
# down of spirand shotel
# i was it said and he said, “how much on the wall
# because i am his and my one cold id to steal
# i should
# ----- diversity: 1.0
# ----- Generating with seed: "om me to you
# tangled up in blue
#
# i lived"
# om me to you
# tangled up in blue
#
# i lived then destlbaly find it and the war to gorth be a houshumusten little ritiona
# next to expect you dossengs above
# the drairgive sarr, why is is lookin’ in the off arean and best o-satacopsection ushe’re
# can the hours hall’s gone never be utning or the funning digmoving his rain, doing the smortan back
# and he were you stopins
# like a boptoney dome, that the ise of that bruaked
# undernearn this grinnin’
# ----- diversity: 1.2
# ----- Generating with seed: "om me to you
# tangled up in blue
#
# i lived"
# om me to you
# tangled up in blue
#
# i lived you aven in frefeel from lordwell meansyangtcur
# runnin’ honey ha
#
# aglilies these knows nothing you cannot?
# bnyin' i’m gonna blow what it sut again
#
# 'ngay by pertafterblougin's the ronghusureuam’s from itters, all
# the pattiram food’t gonna ree”
# go up mister and beatin' guty braverakes then
# country, we tight to fowdpa up c lane
# ne, the lander words over brken, he’s askee platted
# you slow that roes
#
# Epoch 22/60
# 219380/219380 [==============================] - 143s 652us/step - loss: 1.3112
#
# ----- Generating text after Epoch: 21
# ----- diversity: 0.2
# ----- Generating with seed: "st arrived here from the coast
# who looke"
# st arrived here from the coast
# who looked around the street
# where the summer was a morning start
# ...
# he happenin’ pillings around above own
# an temay was going youst
# roadsole by temes, rabin layo, the hat’s in my msy to sid low
# ewhity jumperce or side darl
# Epoch 54/60
# 219380/219380 [==============================] - 141s 642us/step - loss: 1.2505
#
# ----- Generating text after Epoch: 53
# ----- diversity: 0.2
# ----- Generating with seed: "t my arms around you
# and so i beg you: l"
# t my arms around you
# and so i beg you: le
# i was a shot of the way
# when i was a face with me
#
# i got a course that i was a man and the country story
#
# well, i was thinking and the bottom of the love
# that i was thinkin’ and the world and the way the window, the window
# was the news the stands and the streets
# with a streets are all around
# and the street and the window
# when you go to the street and the way the window was a street
# and the book
# ----- diversity: 0.5
# ----- Generating with seed: "t my arms around you
# and so i beg you: l"
# t my arms around you
# and so i beg you: le
# when i was just a real so done
#
# well it never ain’t thinkin’ the tree
# and when the town it was my hand
# and the fienty was beginning
# it was bound times are returning from the stars to you where the white just fall
#
# they don’t see what you come that bird all the truth is four by them things that i was with man in the story wants
# he’s a mouse’s got sometimes i was a long time all the wind
#
# the coun
# ----- diversity: 1.0
# ----- Generating with seed: "t my arms around you
# and so i beg you: l"
# t my arms around you
# and so i beg you: le
# but was no mones through your roget near
# resonk in fine cry
# i tcoutat's named for something show thing
# waunds i were wived
# the work of blodime
#
# don’t cause for the botion stained
#
# all the cold all and you had sense with the door my warde,
# and well,’s things you i’m finalon towll
# and they will tetell to know they tell what skiled
# time for the soldierdarled, my thousand thing with man angalt sends
# ----- diversity: 1.2
# ----- Generating with seed: "t my arms around you
# and so i beg you: l"
# t my arms around you
# and so i beg you: lie the wastive i'm wheelle thines of unire
# nobody’s knotched
# cit’s lostfunding with road, you we sa off, i’d nead to sat
# but with theehrommanxing, do your change you aon't it carely bright
# when the jointmemmant’s in towns
# dopily that do that need pitic run
# monts call of thes tells and give brokenid’tistebom.
#
# am i belong acbody who will prope
# mama on sleeph jack eyes
# as i lyake sation’s heard for
# Epoch 55/60
# 219380/219380 [==============================] - 139s 633us/step - loss: 1.2507
#
# ----- Generating text after Epoch: 54
# ----- diversity: 0.2
# ----- Generating with seed: "ed up like mine
#
# well, my head’s full of"
# ed up like mine
#
# well, my head’s full of something there were all the window
# well, i can see you she was a long time and i won't be so shot in the morning from the beginning
# and i can see your face with you
#
# i was a man the blood
# i was a little to me
#
# the water where the devil i was the street
# when you got me that i won’t be so shoes
# i was a man in the corner that i see the street
# i was a man in the morning from the dance with your mind
# ----- diversity: 0.5
# ----- Generating with seed: "ed up like mine
#
# well, my head’s full of"
# ed up like mine
#
# well, my head’s full of the sun
# i can see the day and they did the world
# i went down the bell of a man and the street many and there was a hold of the dark of dreams
# i was the street was just what you see me
#
# sometimes i can say that you’ll rest
# i want to tell the sky to me
# and i look a mening of the world and i ain’t there it must not be in the true
# love that i see the dance with your back
# he said, “yester, a good of t
# ----- diversity: 1.0
# ----- Generating with seed: "ed up like mine
#
# well, my head’s full of"
# ed up like mine
#
# well, my head’s full of heaveny lookin’ and blausy
# there’s no moed that bound to got old
# if you meet all around is if survaym
# and officturse gonna refout much like a poor through the tohwigg
# yeah– pie’s hard them is mean hatrist full
# clean starvind with slatter give it pass?
# dy, the man that i weabnj.”
#
# sure hadneralraden lost
# if it’s not friend out of them the wohlor
# nobody fill out on the damn everamsing bank that lis
# ----- diversity: 1.2
# ----- Generating with seed: "ed up like mine
#
# well, my head’s full of"
# ed up like mine
#
# well, my head’s full of aym’se out canh“keed god rain
# but meveni’ry tell a dishua
# from
# a hfroge on a woman, muchvorman, the muse on! everywhere i worsed to -walks clat few off a beffre.vetce i blowed back tombnink
# it did folsagive peavers her
#  hidies true dollar
# i warmed you ye, i smikes his honerrss
# get wrong up
# gobovie why
# phever anstleg stimpin
# sweet my hand
#
# well, there was one luces, took of eyest lies by,
# you can
# Epoch 56/60
# 219380/219380 [==============================] - 140s 639us/step - loss: 1.2496
#
# ----- Generating text after Epoch: 55
# ----- diversity: 0.2
# ----- Generating with seed: "tay, lady, stay, stay with your man awhi"
# tay, lady, stay, stay with your man awhil
# i was standing on the stars and the world of the way the dead of the bring
# the wind blows of the way to the road
# i was a fair and she said, “you wanna be me
#
# i got the wind blowin’ a man of the stars
# and the stars is the streets
# i’m standin’ on the stars and the way the wind
#
# the street and the streets are stack-a-lee.
#
# “down in the line
#
# i don’t know what i have to the street
# and the morning co
# ----- diversity: 0.5
# ----- Generating with seed: "tay, lady, stay, stay with your man awhi"
# tay, lady, stay, stay with your man awhil
# i got the wind
#
# but i was stack-a-leades of the wind
#
# well, i could have to do it make nobody, i wanna be the sun
# i would not craok anyhos”
# they say, “goin’ the day the stream when you don’t see me that i was a stranger
# i’ve been dreamin’
# i was a little door
# but i know a man of the streets
# the wind of the feet show me that a friend of light for the crazy
# i can stand on the road
# but may you gonna
# ----- diversity: 1.0
# ----- Generating with seed: "tay, lady, stay, stay with your man awhi"
# tay, lady, stay, stay with your man awhin
# well, bures me hes galry.
# and my horse is your mind
#
# i just used feel, afeed, we went and said, “farent him
#
# yondon she learn digmerasked for something like on their oxford to tate
# the his fair and gold’s on a go father to kill his me something that night, now
# i’m sad, baby, ye a remusty line?
# moven jand of thousand days to the same
# backly, the world my home, how down diamonds of supple
# his bye
# ----- diversity: 1.2
# ----- Generating with seed: "tay, lady, stay, stay with your man awhi"
# tay, lady, stay, stay with your man awhig
# i feel twistden for the myselting folsoon sand
# and stay cition was numble.
# take plany that dixie in the breath, what i’m won’t say
# her trouble to take a 'reime he can began van hill-’sesh lear, everyate
# hanging of my dbles knock fumory,
# it was ragglid you
# you's a-gonncopifower
# the man get ozgice though
# sliefude
#
# the hour got tones afjulietacal
# do
# iffine a mamble
# if you gonna bleeped the foolwayi
# Epoch 57/60
# 219380/219380 [==============================] - 140s 638us/step - loss: 1.2489
#
# ----- Generating text after Epoch: 56
# ----- diversity: 0.2
# ----- Generating with seed: "n it or what part i was supposed to play"
# n it or what part i was supposed to play
#
# well, the morning for you
#
# well, the street are sure can be so so she was hard
#
# the same the streets are baby to the street
# they was the same the street and the wind
#
# the train was the street and the way i was not the street
# when the street are your mind
#
# i was the same the world and the train of the world
# i can see me than the train that the street
# and i can see me than the wind
#
# i was the same
# ----- diversity: 0.5
# ----- Generating with seed: "n it or what part i was supposed to play"
# n it or what part i was supposed to play
#
# i wish that much baby have say,
# the world of the street
# don’t wanna believe, alry foot of the child
# i want my side
#
# i was just through which money
#
# well, the truel one best just like the trist
# well, well, you are a face startin' and it firse in the street
# don’t you see the time cry
# guilt mouth will be saying
# and the tread and the says to give it all around
#
# well, i was liftenin’
#
# i wanna be the
# ----- diversity: 1.0
# ----- Generating with seed: "n it or what part i was supposed to play"
# n it or what part i was supposed to playboy?
# for you been standin’ me no kind old stalt
# ca'll read the gebso handmons with nime to stay
#
# i’ve beel done up
# pulled and he’ll ends by the wind
#
# in this gracey working for a pige
# and the side in the king
# you is in the perseli if i didd're your curn
# that she’s gonna doet it up a da.
# take his woods and wedg my hands paint
# copyright we mastery desourh in song at all
#
# well, i instighttimefor your
# ----- diversity: 1.2
# ----- Generating with seed: "n it or what part i was supposed to play"
# n it or what part i was supposed to play me orruls
# wouldn’t to wash me up your name
# you been strangedam holes, love you, stack-sadis miusastgied, babial chicklone, all at no boles
# i did bewen ’neath right ’staut en barron hygeram
# inverstion is junke, hum thar milk
# my say they dare?
# down intere come ow from
# to me wiz"’ll thought as stupple with my life”
# soroy you wor'scauburen in my hun en jujach acmal
#
# well good am i can hide twich
# tel
# Epoch 58/60
# 219380/219380 [==============================] - 141s 644us/step - loss: 1.2457
#
# ----- Generating text after Epoch: 57
# ----- diversity: 0.2
# ----- Generating with seed: " sang such a sweet melody
# oh, the locust"
#  sang such a sweet melody
# oh, the locusts sang of the day the water with a stream
# she said i had to be a shore
# but i see the things the way i was a grave blood
#
# well, i go to tell you to the steat
# the ship off the street and the water that i was in the morning from the bell
# i don’t know it was a strengther that i was a shore
# when the sun to the story and the way i can see me to the back
# the thing the crying is a shore
# i was the sun is
# ----- diversity: 0.5
# ----- Generating with seed: " sang such a sweet melody
# oh, the locust"
#  sang such a sweet melody
# oh, the locusts sang of the sun there was going and i got a little panchin’
# on the same on the change they can tell me
#
# well, i go to be a man in the one
#
# i don’t leave a lonesome in the dark and sing them the serion father was brokened
# the world that i saw you to the stet blowing
#
# well, they see the past of down
# the winding like a boat and the things that is the window
# all of the walls are the one
#
# i know i lo
# ----- diversity: 1.0
# ----- Generating with seed: " sang such a sweet melody
# oh, the locust"
#  sang such a sweet melody
# oh, the locusts sangal stilks feels or you near alley fight
#
# most cerkie, fell change, the bowat rollin’ the b
# but a sagal i'll blest back for you
# pleaset last the strengther and behindas never find you
#
# i know, but the sun ontise a door
# sad-eyed love yeareven ya heard a fore,
# you're words is pocked, just like a thick, no more’s borkin' with andire
# slahin’ that both grandhle saw to work
# the night a tearyso the
# ----- diversity: 1.2
# ----- Generating with seed: " sang such a sweet melody
# oh, the locust"
#  sang such a sweet melody
# oh, the locusts sorecin of a knotten the pass
# into we may, you know you haven't you dres
# coqueoplove me
# waiting on the tile
# don’t look yonce, baby fish thinkin'
# therongeroid same a rumbling
# and howd wing
#
# well, it’s only febn all shake afreiness
# polifie a petces upas dream somewhere
# but she called any fire
# to ope feel steiled louilt up everyway
# wrong we think out destrugorta farly day
# and am i ding
# the town he’
# Epoch 59/60
# 219380/219380 [==============================] - 141s 643us/step - loss: 1.2453
#
# ----- Generating text after Epoch: 58
# ----- diversity: 0.2
# ----- Generating with seed: "your cage shall be decked with gold
# and "
# your cage shall be decked with gold
# and the way they was all around
#
# i was the song is beat
# and the walls of the way
# and they walked here to the street
# and the walls of the walls
# they can tell you to the reason
# then they want to me the window
# well, i can see the well of the wall
# i can see the wall i was the walls
# they walked all the way
#
# well, i was born to the world and the walls
# to the road to the street
# and i was hard to tell you the
# ----- diversity: 0.5
# ----- Generating with seed: "your cage shall be decked with gold
# and "
# your cage shall be decked with gold
# and they’re on the rain
# through the last the morning he must be comes to the logd, they can see it from the fire
# and started of the way of the locusts gone
#
# they made our back to me the commonce of the wall
# it was so long and bend of the reasory
# lay down the door
#
# you might take up at the best
# as just are your face straight
# and come and i come the more
#
# i wonder what is the morning of the gun
# in the o
# ----- diversity: 1.0
# ----- Generating with seed: "your cage shall be decked with gold
# and "
# your cage shall be decked with gold
# and it’s bedlever years
# it's flowing of the ground
# and i’m gonna llowe thah thpretter
# i’m standin’ out of the moon
# tonight come in my own sait
# says, “his ronge
# darlin’ changed, what’s gone, lay inta they part now
# these smokey builds were comes was drifts at the wiver now to point
# but jack them to diet’s rose
# while on me i wouldn’t be to kicw.i thing on an earty angersicy
# the hair are names i'm forevio
# ----- diversity: 1.2
# ----- Generating with seed: "your cage shall be decked with gold
# and "
# your cage shall be decked with gold
# and e-blinds beganey far or
# passing the rises rewill like ’c alighe warmems
# when you tould to spend and singed quace
# for oe’s east intverion girl
# 'cause trewreze reaking,
# not ya come out to redon
# out knot you found
# that is landerss romentin’ kindly guarnh before she don't hat.
#
# jokermaginalty rainin' a place
# but tt., humlide oh lave under me in love,
# luked were guth and hevers roal across the colla re
# Epoch 60/60
# 219380/219380 [==============================] - 141s 645us/step - loss: 1.2426
#
# ----- Generating text after Epoch: 59
# ----- diversity: 0.2
# ----- Generating with seed: " i saw you dug up
#
# (chorus)
#
# look down a"
#  i saw you dug up
#
# (chorus)
#
# look down and the corner and the way that i could be standing the day
# i was all the sun can believe
# i was a million miss to the road
#
# the pain the streets was started of the back
# the corners of the window
# and the way that the corner and the bord.
#
# there’s a true lovers to the road
#
# the hand of the street was the strings and the street and the sun comes to the hour in the road
#
# well, i’m gonna break you that
# ----- diversity: 0.5
# ----- Generating with seed: " i saw you dug up
#
# (chorus)
#
# look down a"
#  i saw you dug up
#
# (chorus)
#
# look down and the other the road with this crowd
# i was thinking of the face
#
# someone’s gone and the feet of the part
# i neveres and when you look at the stars in the barriess and the crowd of a bad
# then i was rided so sile
# and i can see the door
#
# i want you in the orse i’m alring the street and singer and the break of day
# there’s so i was a thing in the sound
# don’t have to be a distance
# it’s a thing of the fe
# ----- diversity: 1.0
# ----- Generating with seed: " i saw you dug up
#
# (chorus)
#
# look down a"
#  i saw you dug up
#
# (chorus)
#
# look down and me as love
#
# get of our place out from all about you and you take the door
# dark by a guth for me, i’m a gottering in the grade, i think they am i gote
#
# bangles around my fight
#
# now with you!,
#
# tooocjugger to it to creat me, twentle up of the finecummest in the his loud
# in the fectang and mercy
# or ya go up and my home and happy sand you made in the morning, no,
# and she said, “he said, “bansel’s
# ----- diversity: 1.2
# ----- Generating with seed: " i saw you dug up
#
# (chorus)
#
# look down a"
#  i saw you dug up
#
# (chorus)
#
# look down and bried from the wife, glidn hit i waters and yer an,brod i gote?
# i am downtrang brasse, i don’t matter go your kind
# but i don!
# we’s a sendin’ of the boy a, love that you’cake off my should wonder
# will kicks your hand of wheaster al or you, the big life
# she said, “i win't says
# an’ i can’t leas it
# you just live or in lahies
# then i'm gone ooh, i don’t can   "icaus, for you trouble
# lodimsied by hon

# %%
# Save the model
model.save('model1.h5')

# %%
import keras

# Recreate the exact same model purely from the file
new_model = keras.models.load_model('model1.h5')
